# %%
# dataset : https://www.kaggle.com/shwetabh123/mall-customers
# github : https://github.com/pranav567/AI-ML-Lab/tree/master/experiment-5

# %%
import matplotlib.pyplot as plot
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('Mall_Customers.csv')
clustering_data = df[["AnnualIncome","SpendingScore"]]
clustering_data
# Out:
#      AnnualIncome  SpendingScore
# 0              15             39
# 1              15             81
# 2              16              6
# 3              16             77
# 4              17             40
# ..            ...            ...
# 195           120             79
# 196           126             28
# 197           126             74
# 198           137             18
# 199           137             83
#
# [200 rows x 2 columns]

# %%
x = clustering_data.values
x
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
plot.scatter(clustering_data.AnnualIncome.to_list() , clustering_data.SpendingScore.to_list())
plot.title("Mall customers Spending Score")
plot.xlabel("Annual Income")
plot.ylabel("Spending Score")
plot.show()

# %%
def get_wcss(X):
    wcss_list= []
    for i in range(1, 11):  
        kmeans = KMeans(n_clusters=i, init='k-means++', random_state= 42)  
        kmeans.fit(X)  
        wcss_list.append(kmeans.inertia_)  
    
    return wcss_list

# %%
wcss = get_wcss(x)
[print([i+1,wcss[i]]) for i in range(10)]
plot.plot(range(1, 11), wcss)
plot.title('The Elbow Method Graph')  
plot.xlabel('Number of clusters(k)')  
plot.ylabel('wcss_list')
plot.show()
# Out:
# [1, 269981.28000000014]
# [2, 181363.59595959607]
# [3, 106348.37306211119]
# [4, 73679.78903948837]
# [5, 44448.45544793369]
# [6, 37233.81451071002]
# [7, 30259.657207285458]
# [8, 25011.839349156595]
# [9, 21850.16528258562]
# [10, 19672.07284901432]

# %%
def clustering_kmeans(X,k):
    kmeans = KMeans(n_clusters=k, init='k-means++', random_state= 42)  
    y= kmeans.fit_predict(X)  
    return kmeans,y

# %%
# Using the Elbow method the optimal value of cluster(k) is 5 for the given dataset
k_means, y = clustering_kmeans(x, 5)

# %%
plot.scatter(x[y == 0, 0], x[y == 0, 1], s = 100, c = 'blue', label = 'Cluster 1') #for first cluster  
plot.scatter(x[y == 1, 0], x[y == 1, 1], s = 100, c = 'green', label = 'Cluster 2') #for second cluster  
plot.scatter(x[y== 2, 0], x[y == 2, 1], s = 100, c = 'red', label = 'Cluster 3') #for third cluster  
plot.scatter(x[y == 3, 0], x[y == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4') #for fourth cluster  
plot.scatter(x[y == 4, 0], x[y == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5') #for fifth cluster 
plot.scatter(k_means.cluster_centers_[:, 0], k_means.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroid')   
plot.title('Customers Cluster')  
plot.xlabel('Annual Income')  
plot.ylabel('Spending Score')  
plot.legend()  
plot.show()

# %%
# for other values of cluster(k)

# %%
for i in range(10) :
    k_means, y = clustering_kmeans(x, i+1)
    plot.scatter(x[y == 0, 0], x[y == 0, 1], s = 100, c = 'blue', label = 'Cluster 1') #for first cluster  
    if i>0:
        plot.scatter(x[y == 1, 0], x[y == 1, 1], s = 100, c = 'green', label = 'Cluster 2') #for second cluster  
    if i>1:
        plot.scatter(x[y== 2, 0], x[y == 2, 1], s = 100, c = 'red', label = 'Cluster 3') #for third cluster  
    if i>2:
        plot.scatter(x[y == 3, 0], x[y == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4') #for fourth cluster  
    if i>3:
        plot.scatter(x[y == 4, 0], x[y == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5') #for fifth cluster  
    if i>4:
        plot.scatter(x[y == 5, 0], x[y == 5, 1], s = 100, c = 'black', label = 'Cluster 6') #for sixth cluster  
    if i>5:
        plot.scatter(x[y == 6, 0], x[y == 6, 1], s = 100, c = 'purple', label = 'Cluster 7') #for seventh cluster  
    if i>6:
        plot.scatter(x[y == 7, 0], x[y == 7, 1], s = 100, c = 'orange', label = 'Cluster 8') #for eigth cluster  
    if i>7:
        plot.scatter(x[y == 8, 0], x[y == 8, 1], s = 100, c = 'indigo', label = 'Cluster 9') #for ninth cluster  
    if i>8:
        plot.scatter(x[y == 9, 0], x[y == 9, 1], s = 100, c = 'brown', label = 'Cluster 10') #for tenth cluster  
    plot.scatter(k_means.cluster_centers_[:, 0], k_means.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroid')   
    plot.title('Customers Cluster for k = ' + str(i+1))  
    plot.xlabel('Annual Income')  
    plot.ylabel('Spending Score')  
    plot.legend()  
    plot.show()
